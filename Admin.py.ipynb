# %%
import json
class Admin:
    
    def __init__(self):
        
        self.food_item ={}
        self.food_id =len(self.food_item) + 1
    
    def add_new_food_item(self):
        
        self.name =input("Enter the name of food:")
        self.quantity =int(input("Enter the quantity of food:"))
        self.price =int(input("Enter the price of food:"))
        self.discount =int(input("Enter the discount of food:"))
        self.stock =int(input("Enter the stock of food:"))
        
        self.item ={"Food Name":self.name,"Food Quantity":self.quantity,"Food Price":self.price,"Food Stock":self.stock,"Food Discount":self.discount}
        
        self.food_id =len(self.food_item)+1
        self.food_item[self.food_id] =self.item
        print(_*10)

        with open("Food_Item.json","w") as f:
            json.dump(self.food_item,f)
        return self.food_item
    
    def view_food_item(self):
        for i,j in self.food_item.items():
            print(list((i,j)))
        return ""
            
    
    def edit_food_item(self):
        food_id= int(input("Enter the food id you want to edit:"))
        for i in self.food_item[self.food_id]:
            self.food_item[food_id]["Food Name"]="Biriyani"
            self.food_item[food_id]["Food Quantity"]=3
            self.food_item[food_id]["Food Price"]=200
            self.food_item[food_id]["Food Discount"]=10
            self.food_item[food_id]["Food Stock"]=10
            
        with open("Food_Item.json","w") as f:
            json.dump(self.food_item,f)
        print("Updated food items:",self.food_item) 
        return ""
            
    def remove_food_item(self):
        food_item = int(input("Enter the food id you want to remove:"))
        del self.food_item[food_item]
        
        with open("Food_Item.json","w") as f:
            json.dump(self.food_item,f)
        print("Remaining food items:",self.food_item)
        
ad=Admin()
print(ad.add_new_food_item())
print(_*10)
print(ad.add_new_food_item())
print(_*10)
print(ad.add_new_food_item())
print(_*10)
print(ad.view_food_item())
print(_*10)
print(ad.edit_food_item())
print(_*10)
print(ad.remove_food_item())
# Out:
# Enter the name of food:Tandoori Chicken
# Enter the quantity of food:4
# Enter the price of food:240
# Enter the discount of food:10
# Enter the stock of food:10
#
# {1: {'Food Name': 'Tandoori Chicken', 'Food Quantity': 4, 'Food Price': 240, 'Food Stock': 10, 'Food Discount': 10}}
#
# Enter the name of food:Vegan Burger
# Enter the quantity of food:1
# Enter the price of food:320
# Enter the discount of food:10
# Enter the stock of food:10
#
# {1: {'Food Name': 'Tandoori Chicken', 'Food Quantity': 4, 'Food Price': 240, 'Food Stock': 10, 'Food Discount': 10}, 2: {'Food Name': 'Vegan Burger', 'Food Quantity': 1, 'Food Price': 320, 'Food Stock': 10, 'Food Discount': 10}}
#
# Enter the name of food:Truffle Cake
# Enter the quantity of food:1
# Enter the price of food:900
# Enter the discount of food:10
# Enter the stock of food:2
#
# ...
